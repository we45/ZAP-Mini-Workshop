# %% [markdown]
# ## ZAP Mini Workshop
#
# #### Abhay Bhargav - we45
#
# #### Objective
# Over the last 2 years, I have worked with and implemented several SAST and DAST tools as part of a Continuous Delivery Pipeline. In this time, I have seen that there are few tools that match the flexibility and capabilities of OWASP's Zed Attack Proxy, especially from the perspective of integrating into a Continuous Delivery Pipeline.
#
# As part of training programs that I have delivered at OWASP AppSecUSA, EU and DEFCON, I have trained several folks on OWASP ZAP's API and Scripting features. This is a shorter version of the same training program that I have delivered in these places.
#
# The objective of this is as follows:
# - To get someone quickly up and running with ZAP and its feature-rich API and Scripting Features
# - To NOT use presentations. It takes FOREVER prepping presentation. Writing everything in Markdown and Python is far easier
# - To cover essential functionality that I think would be useful to folks. I am sure I will be missing some cool features here. Please bear with me
# - To reference some other useful tools and libraries that I have been working with, either ZAP related or otherwise.
#
# #### Requirements
# - Python 3.6.1
# - Please install all requirements from `requirements.txt`. This includes ZAP's Python API
# - Download and Install ZAP 2.7.0 (Download from (here)[https://github.com/zaproxy/zaproxy/wiki/Downloads])
#
# #### Warnings
# This code is given to you as is, where is. I don't take any responsibility for how/where you use it. This is NOT production ready in any way.
#
# #### Thanks
# - I would like to thank Simon Bennetts (@psiinon) and the rest of the OWASP ZAP Development Team. They do a truly admirable job of maintaining and managing ZAP for all of us.
# - I would like to thank a few members of my amazing team! - Nithin, Sharath and Tilak. Thanks for all that you do
#
# #### Other Useful Projects
# - ZAP Robot Framework Integration - https://bitbucket.org/we45abhay/robozap
# - Vulnerable App used in this exercise - https://bitbucket.org/we45abhay/defcon_vul_app/
#
# ###### Let's get started.....

# %% [markdown]
# ### Pre-start Setup Instructions
#
# - Download and Install ZAP
# - Install some plugins from the ZAP Marketplace, namely:
#     - Python Scripting
#     - Export Report
# - You may choose to install several other plugins. However, for this training, you only need these plugins
# - Open ZAP > Tools > Options > API
#     - Make sure that it's enabled, for UI as well
#     ![ZAP API Screen](api_zap.jpg)
#     - I have disabled API key in this case. You can enable if you would like. However, remember that you need the API Key for every call to ZAP's API if you enable the API Key.

# %% [markdown]
# ### ZAP 2.7.0 API
#
# If you enable the UI Option in ZAP's API Options screen (as done above), you will have access to ZAP's API directly over the browser. You will typically have ZAP running on port 8080 of your localhost. In my case, I have it running on port 8090
#
# The API is available only when you have started ZAP.
#
# ![ZAP API Screen](api_screen.jpg)
#
# Very soon, we are going to start zap using ZAP's CLI and get it up and running. This is very useful when you want to start ZAP without using the UI.

# %%
# we will be using python's subprocess to start ZAP in GUI and headless modes

import subprocess
import os

#GUI ZAP
base_path = '/Applications/OWASP_ZAP.app/Contents/Java/'
gui_command = base_path + 'zap.sh -config api.disablekey=true -port 8090'
# you can use the config param to specify set specific configurations you need when you launch the CLI.
# In this case, I am (actually don't need to) starting ZAP with the API Key disabled and listening port 8090

headless_command = base_path + 'zap.sh -daemon -config api.disablekey=true -port 8090'
#by specifying 'daemon' in the CLI, ZAP starts in Headless mode

zap_process = subprocess.Popen(gui_command.split(' '), stdout = open(os.devnull, 'w'))

# %% [markdown]
# If you have run the code above correctly, you should see that ZAP is now running in GUI Mode. We will be using GUI Mode for this workshop, so you can easily see everything going on within ZAP.
#
# Now that we have ZAP open and running, let's use its API to perform some scans. I will be using it's Python API to perform this. However, ZAP can be used with Java, JavaScript, PHP, Ruby and directly as a REST API
#
# ##### Links:
# - NPM: https://www.npmjs.com/package/zaproxy
# - Java: https://github.com/zaproxy/zaproxy/releases
# - Ruby: https://github.com/vpereira/owasp_zap
#
# Let's start with running the spider against intentionally vulnerable site `demo.testfire.net`

# %%
from zapv2 import ZAPv2 as ZAP #import ZAP library
import time

zap = ZAP(proxies = {'http': 'http://localhost:8090', 'https': 'http://localhost:8090'})
#setting the local ZAP instance that is open on your local system

target_site = 'http://demo.testfire.net'

zap.urlopen(target_site)
#opens up the the target site. Makes a single GET request

spider_id = zap.spider.scan(target_site)
#this line of code kicks off the ZAP Default Spider. This returns an ID value for the spider

print("Spider ID for the initiated spider scan is: {0}".format(spider_id))


#now we can start monitoring the spider's status
while int(zap.spider.status(spider_id)) < 100:
    print("Current Status of ZAP Spider: {0}%".format(zap.spider.status(spider_id)))
    time.sleep(4)
# Out:
# Spider ID for the initiated spider scan is: 1
# Current Status of ZAP Spider: 0%
# Current Status of ZAP Spider: 10%
# Current Status of ZAP Spider: 10%
# Current Status of ZAP Spider: 30%
# Current Status of ZAP Spider: 47%
# Current Status of ZAP Spider: 55%
# Current Status of ZAP Spider: 55%
# Current Status of ZAP Spider: 71%
# Current Status of ZAP Spider: 83%
# Current Status of ZAP Spider: 90%
# Current Status of ZAP Spider: 92%
# Current Status of ZAP Spider: 93%

# %% [markdown]
# If everything went well, you should see that the spider ran successfully, and identified a bunch of in-scope and Out of scope URLs and params.
#
# Before we proceed with scans and other "vulnerability discovery" activities. Let's get some information about the target site from ZAP's API
#
# #### Enumerating the Target Site
#
# ##### Information about the app's content - List of URLs

# %%
#fetch list of urls enumerated by ZAP
zap.core.urls()
# Out:
# ['http://demo.testfire.net',
#  'http://demo.testfire.net/admin',
#  'http://demo.testfire.net/admin/clients.xls',
#  'http://demo.testfire.net/admin',
#  'http://demo.testfire.net/bank',
#  'http://demo.testfire.net/bank/20060308_bak/',
#  'http://demo.testfire.net/bank/account.aspx',
#  'http://demo.testfire.net/bank/account.aspx.cs',
#  'http://demo.testfire.net/bank/apply.aspx',
#  'http://demo.testfire.net/bank/apply.aspx.cs',
#  'http://demo.testfire.net/bank/bank.master',
#  'http://demo.testfire.net/bank/bank.master.cs',
#  'http://demo.testfire.net/bank/customize.aspx',
#  'http://demo.testfire.net/bank/customize.aspx.cs',
#  'http://demo.testfire.net/bank/login.aspx',
#  'http://demo.testfire.net/bank/login.aspx',
#  'http://demo.testfire.net/bank/login.aspx.cs',
#  'http://demo.testfire.net/bank/logout.aspx',
#  'http://demo.testfire.net/bank/logout.aspx.cs',
#  'http://demo.testfire.net/bank/main.aspx',
#  'http://demo.testfire.net/bank/main.aspx.cs',
#  'http://demo.testfire.net/bank/members/',
#  'http://demo.testfire.net/bank/mozxpath.js',
#  'http://demo.testfire.net/bank/queryxpath.aspx',
#  'http://demo.testfire.net/bank/queryxpath.aspx.cs',
#  'http://demo.testfire.net/bank/servererror.aspx',
#  'http://demo.testfire.net/bank/transaction.aspx',
#  'http://demo.testfire.net/bank/transaction.aspx.cs',
#  'http://demo.testfire.net/bank/transfer.aspx',
#  'http://demo.testfire.net/bank/transfer.aspx.cs',
#  'http://demo.testfire.net/bank/ws.asmx',
#  'http://demo.testfire.net/bank/ws.asmx?disco',
#  'http://demo.testfire.net/bank/ws.asmx?op=TransferBalance',
#  'http://demo.testfire.net/bank/ws.asmx?wsdl',
#  'http://demo.testfire.net/bank/ws.asmx?WSDL',
#  'http://demo.testfire.net/bank/',
#  'http://demo.testfire.net/cgi.exe',
#  'http://demo.testfire.net/comment.aspx',
#  'http://demo.testfire.net/comment.aspx',
#  'http://demo.testfire.net/default.aspx',
#  'http://demo.testfire.net/default.aspx?content=jobs/20061027.htm',
#  'http://demo.testfire.net/disclaimer.htm?url=http://www.netscape.com',
#  'http://demo.testfire.net/feedback.aspx',
#  'http://demo.testfire.net/high_yield_investments.htm',
#  'http://demo.testfire.net/images',
#  'http://demo.testfire.net/images',
#  'http://demo.testfire.net/images/adobe.gif',
#  'http://demo.testfire.net/images/altoro.gif',
#  'http://demo.testfire.net/images/b_cards.jpg',
#  'http://demo.testfire.net/images/b_deposit.jpg',
#  'http://demo.testfire.net/images/b_insurance.jpg',
#  'http://demo.testfire.net/images/b_lending.jpg',
#  'http://demo.testfire.net/images/b_main.jpg',
#  'http://demo.testfire.net/images/b_other.jpg',
#  'http://demo.testfire.net/images/b_retirement.jpg',
#  'http://demo.testfire.net/images/cancel.gif',
#  'http://demo.testfire.net/images/header_pic.jpg',
#  'http://demo.testfire.net/images/home1.jpg',
#  'http://demo.testfire.net/images/home2.jpg',
#  'http://demo.testfire.net/images/home3.jpg',
#  'http://demo.testfire.net/images/icon_top.gif',
#  'http://demo.testfire.net/images/inside1.jpg',
#  'http://demo.testfire.net/images/inside3.jpg',
#  'http://demo.testfire.net/images/inside4.jpg',
#  'http://demo.testfire.net/images/inside5.jpg',
#  'http://demo.testfire.net/images/inside6.jpg',
#  'http://demo.testfire.net/images/inside7.jpg',
#  'http://demo.testfire.net/images/logo.gif',
#  'http://demo.testfire.net/images/ok.gif',
#  'http://demo.testfire.net/images/p_cards.jpg',
#  'http://demo.testfire.net/images/p_checking.jpg',
#  'http://demo.testfire.net/images/p_deposit.jpg',
#  'http://demo.testfire.net/images/p_investments.jpg',
#  'http://demo.testfire.net/images/p_loans.jpg',
#  'http://demo.testfire.net/images/p_main.jpg',
#  'http://demo.testfire.net/images/p_other.jpg',
#  'http://demo.testfire.net/images/pf_lock.gif',
#  'http://demo.testfire.net/images/spacer.gif',
#  'http://demo.testfire.net/inside_points_of_interest.htm',
#  'http://demo.testfire.net/notfound.aspx?aspxerrorpath=/Privacypolicy.aspx',
#  'http://demo.testfire.net/pr/',
#  'http://demo.testfire.net/pr',
#  'http://demo.testfire.net/pr/communityannualreport.pdf',
#  'http://demo.testfire.net/pr/Docs.xml',
#  'http://demo.testfire.net/pr/Draft.rtf',
#  'http://demo.testfire.net/pr/Q3_earnings.rtf',
#  'http://demo.testfire.net/Privacypolicy.aspx?sec=Careers&template=US',
#  'http://demo.testfire.net/retirement.htm',
#  'http://demo.testfire.net/robots.txt',
#  'http://demo.testfire.net/search.aspx?txtSearch=ZAP',
#  'http://demo.testfire.net/security.htm',
#  'http://demo.testfire.net/sitemap.xml',
#  'http://demo.testfire.net/style.css',
#  'http://demo.testfire.net/survey_questions.aspx',
#  'http://demo.testfire.net/survey_questions.aspx?step=b']

# %% [markdown]
# Let's fetch some content types from the site with ZAP's API

# %%
zap.stats.site_stats(site = target_site)
# Out:
# [{'stats.code.200': 212,
#   'stats.code.301': 6,
#   'stats.code.302': 4,
#   'stats.code.401': 2,
#   'stats.code.403': 4,
#   'stats.code.404': 18,
#   'stats.code.500': 6,
#   'stats.contentType.application/javascript': 2,
#   'stats.contentType.application/octet-stream': 3,
#   'stats.contentType.application/pdf': 3,
#   'stats.contentType.application/rtf': 3,
#   'stats.contentType.application/vnd.ms-excel': 3,
#   'stats.contentType.image/gif': 15,
#   'stats.contentType.image/jpeg': 49,
#   'stats.contentType.text/css': 3,
#   'stats.contentType.text/html': 35,
#   'stats.contentType.text/html; charset=UTF-8': 7,
#   'stats.contentType.text/html; charset=utf-8': 124,
#   'stats.contentType.text/plain': 3,
#   'stats.contentType.text/xml': 4,
#   'stats.contentType.text/xml; charset=utf-8': 4,
#   'stats.responseTime.1024': 46,
#   'stats.responseTime.16384': 3,
#   'stats.responseTime.2048': 12,
#   'stats.responseTime.256': 24,
#   'stats.responseTime.4096': 4,
#   'stats.responseTime.512': 160,
#   'stats.responseTime.8192': 3,
#   'stats.tag.Comment': 42,
#   'stats.tag.Form': 122,
#   'stats.tag.Hidden': 3,
#   'stats.tag.Object': 3,
#   'stats.tag.Password': 5,
#   'stats.tag.Script': 13,
#   'stats.tag.SetCookie': 12}]

# %% [markdown]
# Now, I am not sure if you noticed, but ZAP automatically starts gathering some details about vulnerabilities in the site using its `Passive Scan` Feature. This is very useful to silently enumerate vulnerabilites related to HTTP Headers, Session Tokens, etc without actually firing attack packets at the target.
#
# #### Let's look at the stuf that ZAP Scans for passively...

# %%
zap.pscan.scanners
# Out:
# [{'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '50001',
#   'name': 'Script Passive Scan Rules',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '50003',
#   'name': 'Stats Passive Scan Rule',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '90022',
#   'name': 'Application Error Disclosure',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10015',
#   'name': 'Incomplete or No Cache-control and Pragma HTTP Header Set',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10019',
#   'name': 'Content-Type Header Missing',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10010',
#   'name': 'Cookie No HttpOnly Flag',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10011',
#   'name': 'Cookie Without Secure Flag',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10017',
#   'name': 'Cross-Domain JavaScript Source File Inclusion',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10016',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10040',
#   'name': 'Secure Pages Include Mixed Content',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10012',
#   'name': 'Password Autocomplete in Browser',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '2',
#   'name': 'Private IP Disclosure',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '3',
#   'name': 'Session ID in URL Rewrite',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10021',
#   'name': 'X-Content-Type-Options Header Missing',
#   'quality': 'release'},
#  {'alertThreshold': 'DEFAULT',
#   'enabled': 'true',
#   'id': '10020',
#   'name': 'X-Frame-Options Header Scanner',
#   'quality': 'release'}]

# %% [markdown]
# As you can see from the above output, some of these are enabled and some are disabled. The number of findings from the Passive Scan are correlated with the number of URls that are crawled by ZAP. Before we go deep into vulnerability scanning, you can actually see the existing vulnerabilities that have been identified by ZAP with this...

# %%
# get an existing list of vulnerabilities
zap.core.alerts(baseurl=target_site)
# Out:
# [{'alert': 'Cookie No HttpOnly Flag',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': 'A cookie has been set without the HttpOnly flag, which means that the cookie can be accessed by JavaScript. If a malicious script can be run on this page then the cookie will be accessible and can be transmitted to another site. If this is a session cookie then session hijacking may be possible.',
#   'evidence': 'Set-Cookie: amSessionId',
#   'id': '0',
#   'messageId': '1',
#   'method': 'GET',
#   'name': 'Cookie No HttpOnly Flag',
#   'other': '',
#   'param': 'amSessionId',
#   'pluginId': '10010',
#   'reference': 'http://www.owasp.org/index.php/HttpOnly',
#   'risk': 'Low',
#   'solution': 'Ensure that the HttpOnly flag is set for all cookies.',
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/',
#   'wascid': '13'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '1',
#   'messageId': '1',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '2',
#   'messageId': '1',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '3',
#   'messageId': '1',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/',
#   'wascid': '15'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '4',
#   'messageId': '7',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/robots.txt',
#   'wascid': '15'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '9',
#   'messageId': '9',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/sitemap.xml',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '10',
#   'messageId': '46',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '11',
#   'messageId': '46',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '12',
#   'messageId': '46',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '13',
#   'messageId': '47',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '14',
#   'messageId': '47',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '15',
#   'messageId': '47',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '16',
#   'messageId': '48',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/login.aspx',
#   'wascid': '14'},
#  {'alert': 'Password Autocomplete in Browser',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '525',
#   'description': 'The AUTOCOMPLETE attribute is not disabled on an HTML FORM/INPUT element containing password type input.  Passwords may be stored in browsers and retrieved.',
#   'evidence': '<input type="password" id="passw" name="passw" style="width: 150px;">',
#   'id': '17',
#   'messageId': '48',
#   'method': 'GET',
#   'name': 'Password Autocomplete in Browser',
#   'other': '',
#   'param': 'passw',
#   'pluginId': '10012',
#   'reference': 'http://www.w3schools.com/tags/att_input_autocomplete.asp\nhttps://msdn.microsoft.com/en-us/library/ms533486%28v=vs.85%29.aspx',
#   'risk': 'Low',
#   'solution': "Turn off the AUTOCOMPLETE attribute in forms or individual input elements containing password inputs by using AUTOCOMPLETE='OFF'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/login.aspx',
#   'wascid': '15'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '18',
#   'messageId': '48',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/login.aspx',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '19',
#   'messageId': '48',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/login.aspx',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '20',
#   'messageId': '51',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside_contact.htm',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '21',
#   'messageId': '51',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside_contact.htm',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '22',
#   'messageId': '51',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside_contact.htm',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '23',
#   'messageId': '52',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/feedback.aspx',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '24',
#   'messageId': '52',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/feedback.aspx',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '25',
#   'messageId': '52',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/feedback.aspx',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '26',
#   'messageId': '57',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=personal.htm',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '27',
#   'messageId': '57',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=personal.htm',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '28',
#   'messageId': '57',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=personal.htm',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '29',
#   'messageId': '58',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=business.htm',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '30',
#   'messageId': '58',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=business.htm',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '31',
#   'messageId': '58',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=business.htm',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '32',
#   'messageId': '61',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside.htm',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '33',
#   'messageId': '61',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside.htm',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '34',
#   'messageId': '61',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=inside.htm',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '35',
#   'messageId': '65',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=personal_checking.htm',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '36',
#   'messageId': '65',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/default.aspx?content=personal_checking.htm',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '37',
#   'messageId': '65',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
# ...
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=GetUserAccounts',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '516',
#   'messageId': '487',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=GetUserAccounts',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '517',
#   'messageId': '487',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=GetUserAccounts',
#   'wascid': '15'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '518',
#   'messageId': '488',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/pr/Q3_earnings.rtf',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '519',
#   'messageId': '489',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=IsValidUser',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '520',
#   'messageId': '489',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=IsValidUser',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '521',
#   'messageId': '489',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=IsValidUser',
#   'wascid': '15'},
#  {'alert': 'Web Browser XSS Protection Not Enabled',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '933',
#   'description': "Web Browser XSS Protection is not enabled, or is disabled by the configuration of the 'X-XSS-Protection' HTTP response header on the web server",
#   'evidence': '',
#   'id': '522',
#   'messageId': '490',
#   'method': 'GET',
#   'name': 'Web Browser XSS Protection Not Enabled',
#   'other': "The X-XSS-Protection HTTP response header allows the web server to enable or disable the web browser's XSS protection mechanism. The following values would attempt to enable it: \nX-XSS-Protection: 1; mode=block\nX-XSS-Protection: 1; report=http://www.example.com/xss\nThe following values would disable it:\nX-XSS-Protection: 0\nThe X-XSS-Protection HTTP response header is currently supported on Internet Explorer, Chrome and Safari (WebKit).\nNote that this alert is only raised if the response body could potentially contain an XSS payload (with a text-based content type, with a non-zero length).",
#   'param': 'X-XSS-Protection',
#   'pluginId': '10016',
#   'reference': 'https://www.owasp.org/index.php/XSS_(Cross_Site_Scripting)_Prevention_Cheat_Sheet\nhttps://blog.veracode.com/2014/03/guidelines-for-setting-security-headers/',
#   'risk': 'Low',
#   'solution': "Ensure that the web browser's XSS filter is enabled, by setting the X-XSS-Protection HTTP response header to '1'.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=TransferBalance',
#   'wascid': '14'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '523',
#   'messageId': '490',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=TransferBalance',
#   'wascid': '15'},
#  {'alert': 'X-Frame-Options Header Not Set',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "X-Frame-Options header is not included in the HTTP response to protect against 'ClickJacking' attacks.",
#   'evidence': '',
#   'id': '524',
#   'messageId': '490',
#   'method': 'GET',
#   'name': 'X-Frame-Options Header Not Set',
#   'other': '',
#   'param': 'X-Frame-Options',
#   'pluginId': '10020',
#   'reference': 'http://blogs.msdn.com/b/ieinternals/archive/2010/03/30/combating-clickjacking-with-x-frame-options.aspx',
#   'risk': 'Medium',
#   'solution': "Most modern Web browsers support the X-Frame-Options HTTP header. Ensure it's set on all web pages returned by your site (if you expect the page to be framed only by pages on your server (e.g. it's part of a FRAMESET) then you'll want to use SAMEORIGIN, otherwise if you never expect the page to be framed, you should use DENY. ALLOW-FROM allows specific websites to frame the web page in supported web browsers).",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?op=TransferBalance',
#   'wascid': '15'},
#  {'alert': 'X-Content-Type-Options Header Missing',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '16',
#   'description': "The Anti-MIME-Sniffing header X-Content-Type-Options was not set to 'nosniff'. This allows older versions of Internet Explorer and Chrome to perform MIME-sniffing on the response body, potentially causing the response body to be interpreted and displayed as a content type other than the declared content type. Current (early 2014) and legacy versions of Firefox will use the declared content type (if one is set), rather than performing MIME-sniffing.",
#   'evidence': '',
#   'id': '525',
#   'messageId': '491',
#   'method': 'GET',
#   'name': 'X-Content-Type-Options Header Missing',
#   'other': 'This issue still applies to error type pages (401, 403, 500, etc) as those pages are often still affected by injection issues, in which case there is still concern for browsers sniffing pages away from their actual content type.\nAt "High" threshold this scanner will not alert on client or server error responses.',
#   'param': 'X-Content-Type-Options',
#   'pluginId': '10021',
#   'reference': 'http://msdn.microsoft.com/en-us/library/ie/gg622941%28v=vs.85%29.aspx\nhttps://www.owasp.org/index.php/List_of_useful_HTTP_headers',
#   'risk': 'Low',
#   'solution': "Ensure that the application/web server sets the Content-Type header appropriately, and that it sets the X-Content-Type-Options header to 'nosniff' for all web pages.\nIf possible, ensure that the end user uses a standards-compliant and modern web browser that does not perform MIME-sniffing at all, or that can be directed by the web application/web server to not perform MIME-sniffing.",
#   'sourceid': '3',
#   'url': 'http://demo.testfire.net/bank/ws.asmx?disco',
#   'wascid': '15'}]
